# %% [markdown]
# <a href="https://colab.research.google.com/github/geekshailender/python3-tutorials/blob/main/tiktoctoe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %%
def display(row1, row2, row3):
  print(row1)
  print(row2)
  print(row3)

# %%
row = [1,2,3]
display(row, row, row)
# Out:
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]

# %%
row[1]= "X"

# %%
display(row, row, row)
# Out:
# [1, 'X', 3]
# [1, 'X', 3]
# [1, 'X', 3]

# %%
pos_index = int(input("Choose an index position: "))
row[pos_index] = "O"
display(row, row, row)
# Out:
# Choose an index position: 2
# [1, 'X', 'O']
# [1, 'X', 'O']
# [1, 'X', 'O']

# %%
pos_value = input("Choose an index position value: ")
row[pos_index] = pos_value
display(row, row, row)
# Out:
# Choose an index position value: X
# [1, 'X', 'X']
# [1, 'X', 'X']
# [1, 'X', 'X']
