# %%
def mytest():
  x='singh'
  print(x)
  x =10

# %%
mytest()
# Out:
# singh

# %%
def vol(rad):
  print((4/3) * (3.14) * (rad**3))

# %%
vol(2)
# Out:
# 33.49333333333333

# %%
def ran_check(num, low , high):
  myn = range(low, high)
  for n in myn:
    if n == num:
      return True
  return False

# %%
ran_check(8,2,7)
# Out:
# False
