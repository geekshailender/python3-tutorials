# %% [markdown]
# <a href="https://colab.research.google.com/github/geekshailender/python3-tutorials/blob/googleColab/21March.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
myList = [1,2,3]

# %%
myset = set()

# %%
myset.add(1)

# %%
myset
# Out:
# {1}

# %%
class Dog():
  def __init__(self, breed):
    self.breed = breed
    print(self)

# %%
my_dog = Dog(breed ='CT')

# %%
my_dog.breed
# Out:
# 'CT'
