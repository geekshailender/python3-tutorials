# %% [markdown]
# <a href="https://colab.research.google.com/github/geekshailender/python3-tutorials/blob/googleColab/22March.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Dog():
  species = 'mammal'
  def __init__(self,breed,name):
    self.breed = breed
    self.name = name
  def bark(self,number):
    print('WOOF! My name is {} and the breed is {}'.format(self.name, self.breed))

# %%
myDOg = Dog('Lab','Frankie')

# %%
myDOg.bark(10)
# Out:
# WOOF! My name is Frankie and the breed is Lab

# %%
class Circle():
  pi = 3.14

  def __init__(self,radius):
    self.radius = radius
    self.area = radius*radius*self.pi

# %%
myCircle = Circle(10)

# %%
myCircle.area
# Out:
# 314.0
